# %% [markdown]
# <a href="https://colab.research.google.com/github/Adamixa/Data_field_job_analysis/blob/main/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Field Jobs Analysis

# %% [markdown]
# ### 1. Data Loading and Initial Exploration:

# %% [markdown]
# Load the selected dataset into your preferred data analysis environment.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from wordcloud import WordCloud

df = pd.read_csv('/content/jobs_in_data_2024.csv', sep = ',') # to read file

# %%
df # to view the dataset
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024      Entry-level       Freelance    Applied Data Scientist
# 1           2024        Executive       Full-time     Business Intelligence
# 2           2024        Executive       Full-time     Business Intelligence
# 3           2024           Senior       Full-time            Data Architect
# 4           2024           Senior       Full-time            Data Architect
# ...          ...              ...             ...                       ...
# 14194       2021           Senior       Full-time           Data Specialist
# 14195       2020           Senior       Full-time            Data Scientist
# 14196       2021        Mid-level       Full-time  Principal Data Scientist
# 14197       2020      Entry-level       Full-time            Data Scientist
# 14198       2020      Entry-level        Contract     Business Data Analyst
#
#        salary salary_currency  salary_in_usd employee_residence work_setting  \
# 0       30000             USD          30000     United Kingdom       Remote
# 1      230000             USD         230000      United States    In-person
# 2      176900             USD         176900      United States    In-person
# 3      171210             USD         171210             Canada    In-person
# 4       92190             USD          92190             Canada    In-person
# ...       ...             ...            ...                ...          ...
# 14194  165000             USD         165000      United States       Remote
# 14195  412000             USD         412000      United States       Remote
# 14196  151000             USD         151000      United States       Remote
# 14197  105000             USD         105000      United States       Remote
# 14198  100000             USD         100000      United States       Remote
#
#       company_location company_size                    job_category
# 0       United Kingdom            M       Data Science and Research
# 1        United States            M            BI and Visualization
# 2        United States            M            BI and Visualization
# 3               Canada            M  Data Architecture and Modeling
# 4               Canada            M  Data Architecture and Modeling
# ...                ...          ...                             ...
# 14194    United States            L    Data Management and Strategy
# 14195    United States            L       Data Science and Research
# 14196    United States            L       Data Science and Research
# 14197    United States            S       Data Science and Research
# 14198    United States            L                   Data Analysis
#
# [14199 rows x 12 columns]

# %% [markdown]
# Explore the structure of the dataset (number of rows and columns, data types, etc.).

# %%
num_rows, num_cols = df.shape # num of cols and rows
print("Number of rows:", num_rows)
print("Number of columns:", num_cols)
# Out:
# Number of rows: 14199
# Number of columns: 12

# %%
df.dtypes # every column's type
# Out:
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# work_setting          object
# company_location      object
# company_size          object
# job_category          object
# dtype: object

# %% [markdown]
# Examine the first few rows of the dataset to understand its contents

# %%
df.head(3) # show the first 3 rows
# Out:
#    work_year experience_level employment_type               job_title  salary  \
# 0       2024      Entry-level       Freelance  Applied Data Scientist   30000
# 1       2024        Executive       Full-time   Business Intelligence  230000
# 2       2024        Executive       Full-time   Business Intelligence  176900
#
#   salary_currency  salary_in_usd employee_residence work_setting  \
# 0             USD          30000     United Kingdom       Remote
# 1             USD         230000      United States    In-person
# 2             USD         176900      United States    In-person
#
#   company_location company_size               job_category
# 0   United Kingdom            M  Data Science and Research
# 1    United States            M       BI and Visualization
# 2    United States            M       BI and Visualization

# %%
df.tail(3) # show last 3 rows
# Out:
#        work_year experience_level employment_type                 job_title  \
# 14196       2021        Mid-level       Full-time  Principal Data Scientist
# 14197       2020      Entry-level       Full-time            Data Scientist
# 14198       2020      Entry-level        Contract     Business Data Analyst
#
#        salary salary_currency  salary_in_usd employee_residence work_setting  \
# 14196  151000             USD         151000      United States       Remote
# 14197  105000             USD         105000      United States       Remote
# 14198  100000             USD         100000      United States       Remote
#
#       company_location company_size               job_category
# 14196    United States            L  Data Science and Research
# 14197    United States            S  Data Science and Research
# 14198    United States            L              Data Analysis

# %%
df.sample(3) # 3 randoms rows
# Out:
#       work_year experience_level employment_type       job_title  salary  \
# 2470       2024           Senior       Full-time  Data Scientist  136000
# 3037       2024           Senior       Full-time   Data Engineer  181100
# 6945       2023           Senior       Full-time   Data Engineer  269100
#
#      salary_currency  salary_in_usd employee_residence work_setting  \
# 2470             USD         136000      United States       Remote
# 3037             USD         181100      United States    In-person
# 6945             USD         269100      United States    In-person
#
#      company_location company_size               job_category
# 2470    United States            M  Data Science and Research
# 3037    United States            M           Data Engineering
# 6945    United States            M           Data Engineering

# %%
df.columns # names of dataframe
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'work_setting', 'company_location', 'company_size', 'job_category'],
#       dtype='object')

# %% [markdown]
# [Jobs%20and%20Sal.pdf](https://Jobs%20and%20Sal.pdf)

# %% [markdown]
# ### 2. Data Cleaning:

# %% [markdown]
# Handle missing values appropriately (e.g., imputation, deletion, etc.).

# %%
miss_values = df.isnull().sum() # to check missing values
miss_values
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                0
# salary_currency       0
# salary_in_usd         0
# employee_residence    0
# work_setting          0
# company_location      0
# company_size          0
# job_category          0
# dtype: int64

# %% [markdown]
# Check for and handle any duplicate entries.

# %%
dup_rows = df.duplicated() # check for duplicate each row
dup_rows
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14194    False
# 14195    False
# 14196    False
# 14197    False
# 14198    False
# Length: 14199, dtype: bool

# %%
df = df.drop(df[df['company_location'] == 'Isreal'].index)
(df[df['company_location'] == 'Isreal'])
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, work_setting, company_location, company_size, job_category]
# Index: []

# %% [markdown]
# Convert categorical variables into the appropriate data type if necessary

# %%
df['salary'] = df['salary'].astype(float) # convert salary column from int to float
df.dtypes
# Out:
# work_year               int64
# experience_level       object
# employment_type        object
# job_title              object
# salary                float64
# salary_currency        object
# salary_in_usd           int64
# employee_residence     object
# work_setting           object
# company_location       object
# company_size           object
# job_category           object
# dtype: object

# %%
df['salary_in_usd'] = df['salary_in_usd'].astype(float) # convert salary in usd column from int to float
df.dtypes
# Out:
# work_year               int64
# experience_level       object
# employment_type        object
# job_title              object
# salary                float64
# salary_currency        object
# salary_in_usd         float64
# employee_residence     object
# work_setting           object
# company_location       object
# company_size           object
# job_category           object
# dtype: object

# %% [markdown]
# Dealing with outliers:

# %%
df.describe()
# Out:
#           work_year         salary  salary_in_usd
# count  14199.000000   14199.000000    14199.00000
# mean    2023.110501  149057.514262   149472.04944
# std        0.686929   64932.044143    64379.26016
# min     2020.000000   14000.000000    15000.00000
# 25%     2023.000000  102150.000000   104000.00000
# 50%     2023.000000  142000.000000   142000.00000
# 75%     2024.000000  185900.000000   185900.00000
# max     2024.000000  450000.000000   450000.00000

# %%
Q1 = df['salary_in_usd'].quantile(0.25)
Q3 = df['salary_in_usd'].quantile(0.75)
IQR = Q3-Q1

# %%
lower_lim = Q1 - 1.5 * IQR
upper_lim = Q3 + 1.5 * IQR

# %%
lower_lim
# Out:
# -18850.0

# %%
upper_lim
# Out:
# 308750.0

# %%
outliers_low = (df['salary_in_usd'] < lower_lim)
outliers_high = (df['salary_in_usd'] > upper_lim)
len(df['salary_in_usd']) - (len(df['salary_in_usd'][outliers_low])+(len(df['salary_in_usd'][outliers_high])))
# Out:
# 13938

# %%
df['salary_in_usd'][outliers_high | outliers_low]
# Out:
# 19       322000.0
# 53       331292.0
# 86       363000.0
# 88       345000.0
# 110      440000.0
#            ...
# 14001    450000.0
# 14131    416000.0
# 14148    325000.0
# 14192    423000.0
# 14195    412000.0
# Name: salary_in_usd, Length: 261, dtype: float64

# %%
df['salary_in_usd'][~(outliers_high | outliers_low)]
# Out:
# 0         30000.0
# 1        230000.0
# 2        176900.0
# 3        171210.0
# 4         92190.0
#            ...
# 14193     28369.0
# 14194    165000.0
# 14196    151000.0
# 14197    105000.0
# 14198    100000.0
# Name: salary_in_usd, Length: 13938, dtype: float64

# %%
df = df[~(outliers_high | outliers_low)]

# %%
df
# Out:
#        work_year experience_level employment_type                 job_title  \
# 0           2024      Entry-level       Freelance    Applied Data Scientist
# 1           2024        Executive       Full-time     Business Intelligence
# 2           2024        Executive       Full-time     Business Intelligence
# 3           2024           Senior       Full-time            Data Architect
# 4           2024           Senior       Full-time            Data Architect
# ...          ...              ...             ...                       ...
# 14193       2021        Mid-level       Full-time             Data Engineer
# 14194       2021           Senior       Full-time           Data Specialist
# 14196       2021        Mid-level       Full-time  Principal Data Scientist
# 14197       2020      Entry-level       Full-time            Data Scientist
# 14198       2020      Entry-level        Contract     Business Data Analyst
#
#          salary salary_currency  salary_in_usd employee_residence  \
# 0       30000.0             USD        30000.0     United Kingdom
# 1      230000.0             USD       230000.0      United States
# 2      176900.0             USD       176900.0      United States
# 3      171210.0             USD       171210.0             Canada
# 4       92190.0             USD        92190.0             Canada
# ...         ...             ...            ...                ...
# 14193   24000.0             EUR        28369.0              Malta
# 14194  165000.0             USD       165000.0      United States
# 14196  151000.0             USD       151000.0      United States
# 14197  105000.0             USD       105000.0      United States
# 14198  100000.0             USD       100000.0      United States
#
#       work_setting company_location company_size  \
# 0           Remote   United Kingdom            M
# 1        In-person    United States            M
# 2        In-person    United States            M
# 3        In-person           Canada            M
# 4        In-person           Canada            M
# ...            ...              ...          ...
# 14193       Hybrid            Malta            L
# 14194       Remote    United States            L
# 14196       Remote    United States            L
# 14197       Remote    United States            S
# 14198       Remote    United States            L
#
#                          job_category
# 0           Data Science and Research
# 1                BI and Visualization
# 2                BI and Visualization
# 3      Data Architecture and Modeling
# 4      Data Architecture and Modeling
# ...                               ...
# 14193                Data Engineering
# 14194    Data Management and Strategy
# 14196       Data Science and Research
# 14197       Data Science and Research
# 14198                   Data Analysis
#
# [13938 rows x 12 columns]

# %% [markdown]
# ### 3. Exploratory Data Analysis:

# %% [markdown]
# Conduct univariate analysis to understand the distribution of individual variables (e.g., listing prices, number of reviews, etc.).

# %%
df.describe() # summary statistics mean, std, min and max
# Out:
#           work_year         salary  salary_in_usd
# count  13938.000000   13938.000000   13938.000000
# mean    2023.107619  145344.224781  145732.962979
# std        0.686725   59321.183266   58609.942677
# min     2020.000000   14000.000000   15000.000000
# 25%     2023.000000  100000.000000  102000.000000
# 50%     2023.000000  140000.000000  140000.000000
# 75%     2024.000000  185000.000000  184950.000000
# max     2024.000000  409500.000000  308000.000000

# %%
df.describe(include='object') # for non numerical
# Out:
#        experience_level employment_type      job_title salary_currency  \
# count             13938           13938          13938           13938
# unique                4               4            147              12
# top              Senior       Full-time  Data Engineer             USD
# freq               9179           13880           3033           12892
#
#        employee_residence work_setting company_location company_size  \
# count               13938        13938            13938        13938
# unique                 86            3               74            3
# top         United States    In-person    United States            M
# freq                12167         9205            12213        12870
#
#                      job_category
# count                       13938
# unique                         10
# top     Data Science and Research
# freq                         4564

# %%
df['salary'].describe() # statistics of the salary column mean, std, min and max
# Out:
# count     13938.000000
# mean     145344.224781
# std       59321.183266
# min       14000.000000
# 25%      100000.000000
# 50%      140000.000000
# 75%      185000.000000
# max      409500.000000
# Name: salary, dtype: float64

# %%
df['work_setting'].describe() # statistics of the work_setting column
# Out:
# count         13938
# unique            3
# top       In-person
# freq           9205
# Name: work_setting, dtype: object

# %%
df['job_title'].describe() # statistics of the job_title column
# Out:
# count             13938
# unique              147
# top       Data Engineer
# freq               3033
# Name: job_title, dtype: object

# %%
saudi_arabia_data = df[df['company_location'] == 'Saudi Arabia'] # filtering to include only rows where location company is Saudi Arbia
saudi_arabia_data
# Out:
#        work_year experience_level employment_type  \
# 140         2024           Senior       Full-time
# 9493        2023        Mid-level       Full-time
# 10169       2023        Mid-level       Full-time
#
#                                 job_title    salary salary_currency  \
# 140                 AI Research Scientist  150000.0             USD
# 9493   Machine Learning Research Engineer   90000.0             USD
# 10169                  Staff Data Analyst  179998.0             USD
#
#        salary_in_usd employee_residence work_setting company_location  \
# 140         150000.0       Saudi Arabia       Hybrid     Saudi Arabia
# 9493         90000.0       Saudi Arabia       Remote     Saudi Arabia
# 10169       179998.0       Saudi Arabia       Remote     Saudi Arabia
#
#       company_size               job_category
# 140              M  Data Science and Research
# 9493             M  Data Science and Research
# 10169            S              Data Analysis

# %% [markdown]
# Perform bivariate analysis to explore relationships between variables (e.g., price vs. property type, price vs. neighborhood, etc.).

# %%
average_salary = df.groupby('experience_level')['salary_in_usd'].mean() # calc avg salary by experience level

experience_levels = average_salary.index
x = np.arange(len(experience_levels)) # Get unique experience levels and their indices

bar_width = 0.50

plt.bar(x, average_salary, width=bar_width, color='#afc7ff') # grouped bar chart
plt.xticks(x, experience_levels, rotation=45)

plt.xlabel('Experience Level') # lables and title
plt.ylabel('Salary in USD')
plt.title('Average Salary by Experience Level')

plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# This Bar Chart shows us the relationship between Average Salary and Experience level.
#
# As we see Executive receives hightest salary.

# %%
grouped_data = df.groupby('work_year')['salary_in_usd']

fig, ax = plt.subplots()

box_color = '#9fcbfd'

bp = ax.boxplot([grouped_data.get_group(year) for year in grouped_data.groups.keys()], patch_artist=True)

for box in bp['boxes']:
    box.set(facecolor=box_color)

plt.title('Salary Distribution by Work Year')
plt.xlabel('Work Year')
plt.ylabel('Salary in USD')

ax.set_xticklabels(grouped_data.groups.keys())

plt.show()

# %%
sns.kdeplot(x = "salary_in_usd" ,data =df.replace([np.inf, -np.inf], np.nan), fill=True)
plt.title("Salary distribution after dealing with outliers");

# %%
average_salary_by_country = df.groupby('job_title')['salary_in_usd'].mean() # calc the avg salary by country

top_10_countries = average_salary_by_country.nlargest(10) # sort the countries by avg salary and select the top 10
sorted_countries = top_10_countries.sort_values(ascending=True)

plt.figure(figsize=(10, 8)) # horizontal bar chart to show the top 10 countries and their avg salary
plt.barh(sorted_countries.index, sorted_countries.values, color = '#9fcbfd')

plt.xlabel('Average Salary in USD') # labels and title
plt.ylabel('Job Title')
plt.title('Top 10 Job Title with Highest Average Salary')

plt.show()

# %% [markdown]
#  This relationship to get which job title get highest average salary , and It has been analyzed and shown to us Data Science Tech lead recevies the hightes average salary

# %%
df['job_category'].unique()
# Out:
# array(['Data Science and Research', 'BI and Visualization',
#        'Data Architecture and Modeling', 'Data Analysis',
#        'Data Engineering', 'Leadership and Management',
#        'Data Quality and Operations', 'Machine Learning and AI',
#        'Cloud and Database', 'Data Management and Strategy'], dtype=object)

# %%
tgaverage_salary_by_country = df.groupby('company_location')['salary_in_usd'].mean() # calc the avg salary by country

top_10_countries = average_salary_by_country.nlargest(10) # sort the countries by avg salary and select the top 10
sorted_countries = top_10_countries.sort_values(ascending=True)

plt.figure(figsize=(10, 8)) # horizontal bar chart to show the top 10 countries and their avg salary
plt.barh(sorted_countries.index, sorted_countries.values, color = '#68daf8')

plt.xlabel('Average Salary in USD') # labels and title
plt.ylabel('Country')
plt.title('Top 10 Countries with Highest Average Salary')

plt.show()

# %% [markdown]
# Bar chart representation that displays categorical data with rectangular bar.
#
# This horizontal bar chart shows the top 10 countries and their average salary.
#
# This relationship to get which country paid the highest average salary , and It has been analyzed and shown to us Qatar is paid hightes average salary.

# %% [markdown]
# Visualize the data using appropriate plots (e.g., histograms, box plots, scatter plots, etc.).

# %%
plt.figure(figsize=(10,5))
year_counts = df['work_year'].value_counts().sort_index()

plt.plot(year_counts.index, year_counts.values, marker='*',linestyle='-',color="#68daf8")

plt.xlabel("Year", color = 'black' )
plt.ylabel("Number of Employees", color = 'black')
plt.title("Years of Work", color = 'black')

plt.show()

# %% [markdown]
# As we see, we can conclude that the dataset includes work year from 2020 to 2024 with the highest amount of data from the year 2023

# %%
job_title = ' '.join(df['job_title'].dropna().values) # create string of all job titles

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(job_title) # the word cloud

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Job Titles Word Cloud')
plt.show()

# %% [markdown]
# Word Cloud is a data visualization technique used for representing text data in which the size of each word indicates its frequency or importance.
#
# As we see the most represented word is Data Engineer and Data Scientist.

# %%
category_counts = df['work_setting'].value_counts()
custom_colors = ['#68daf8', '#9fcbfd', '#246C88', '#FFDE59']

plt.figure(figsize=(10, 6))
plt.pie(category_counts, labels=category_counts.index, autopct='%.0f%%', startangle=90, colors=custom_colors)
plt.axis('equal')
plt.title('Distribution of work conditions')
autopct='%.2f'


plt.legend(labels=category_counts.index, loc='best')

plt.show()

# %% [markdown]
# A pie chart is a circular statistical plot that can display only one series of data. The area of the chart is the total percentage of the given data.
#
# This Pie Chart shows the percentage of work conditions
#
# *   Hybird
# *   Remote
# *   In person

# %% [markdown]
# Calculate summary statistics for relevant variables.

# %%
summary_stats_numerical = df.describe() # calc summary statistics for all numerical var
summary_stats_numerical
# Out:
#           work_year         salary  salary_in_usd
# count  13938.000000   13938.000000   13938.000000
# mean    2023.107619  145344.224781  145732.962979
# std        0.686725   59321.183266   58609.942677
# min     2020.000000   14000.000000   15000.000000
# 25%     2023.000000  100000.000000  102000.000000
# 50%     2023.000000  140000.000000  140000.000000
# 75%     2024.000000  185000.000000  184950.000000
# max     2024.000000  409500.000000  308000.000000

# %% [markdown]
# ### 4. Feature Engineering:

# %% [markdown]
# Create new features that might be useful for analysis (e.g., average rating, occupancy rate, etc.).

# %%
avg_salary_by_job = df.groupby('job_title')['salary_in_usd'].mean() # calc avg salary for unique jobs
unique_jobs = df['job_title'].unique()
sample_data = pd.DataFrame({'avg_salary_in_usd_by_job': avg_salary_by_job[unique_jobs]})
sample_data
# Out:
#                          avg_salary_in_usd_by_job
# job_title
# Applied Data Scientist               78216.545455
# Business Intelligence               149104.190476
# Data Architect                      159030.561765
# Data Science                        156956.620112
# Insight Analyst                      46459.916667
# ...                                           ...
# Marketing Data Analyst              144327.000000
# Data Analytics Engineer              78839.400000
# Cloud Data Architect                250000.000000
# Lead Data Engineer                  139230.333333
# Principal Data Analyst              122500.000000
#
# [147 rows x 1 columns]

# %%
data_work = df['work_year'].value_counts().reset_index() # calc the frequency occurrences for each unique value in work year
data_work.columns = ['work_year', 'count']
data_work = data_work.sort_values(by = 'count', ascending=False)
print(data_work)
# Out:
#    work_year  count
# 0       2023   8333
# 1       2024   3718
# 2       2022   1624
# 3       2021    195
# 4       2020     68

# %%
data_job = df['job_category'].value_counts().reset_index() # calc the frequency of occurrences for each unique job category
data_job.columns = ['Job_Category', 'Count']
data_job = data_job.sort_values(by='Count', ascending=False)
print(data_job)
# Out:
#                      Job_Category  Count
# 0       Data Science and Research   4564
# 1                Data Engineering   3129
# 2                   Data Analysis   2199
# 3         Machine Learning and AI   2052
# 4       Leadership and Management    777
# 5            BI and Visualization    600
# 6  Data Architecture and Modeling    412
# 7    Data Management and Strategy    115
# 8     Data Quality and Operations     79
# 9              Cloud and Database     11

# %%
data_engineer_df = df[df['job_title'] == 'Data Engineer'] # filter for data engineers

avg_salary_data_engineer = data_engineer_df['salary_in_usd'].mean() # calc avg salary for data engineers
print("Average Salary for Data Engineers in USD:", avg_salary_data_engineer)
# Out:
# Average Salary for Data Engineers in USD: 145585.98285525883

# %%
average_salary_by_country = df.groupby('employee_residence')['salary_in_usd'].mean() # calc avg salary by country

average_salary_saudi_arabia = average_salary_by_country.loc['Saudi Arabia']
print("Average Salary for Saudi Arabia in USD:", average_salary_saudi_arabia)
# Out:
# Average Salary for Saudi Arabia in USD: 139999.33333333334

# %%
df['employee_expat'] = ~(df['employee_residence'] == df['company_location']) # create a feature for is_employee_expat

df['employee_expat'] # the employee residence and company location if the same
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 14193    False
# 14194    False
# 14196    False
# 14197    False
# 14198    False
# Name: employee_expat, Length: 13938, dtype: bool

# %%
df.query("employee_expat == True")
# Out:
#        work_year experience_level employment_type                 job_title  \
# 161         2024      Entry-level       Full-time      Admin & Data Analyst
# 2287        2024      Entry-level       Full-time    Data Analytics Manager
# 3188        2024        Mid-level        Contract      AI Research Engineer
# 5451        2023        Mid-level        Contract               AI Engineer
# 5454        2023        Mid-level       Freelance   Data Science Consultant
# ...          ...              ...             ...                       ...
# 14167       2021           Senior       Full-time      Data Science Manager
# 14169       2020           Senior       Freelance  Computer Vision Engineer
# 14178       2020        Mid-level       Full-time            Data Scientist
# 14188       2020        Mid-level       Full-time             Data Engineer
# 14191       2021        Mid-level       Full-time            Data Scientist
#
#          salary salary_currency  salary_in_usd  employee_residence  \
# 161     40000.0             USD        40000.0               India
# 2287    27000.0             USD        27000.0               India
# 3188    57000.0             EUR        63333.0             Croatia
# 5451    50000.0             USD        50000.0             Czechia
# 5454    21000.0             USD        21000.0            Pakistan
# ...         ...             ...            ...                 ...
# 14167  152000.0             USD       152000.0       United States
# 14169   60000.0             USD        60000.0  Russian Federation
# 14178   55000.0             EUR        62726.0              France
# 14188  130800.0             USD       130800.0               Spain
# 14191  160000.0             SGD       119059.0           Singapore
#
#       work_setting company_location company_size               job_category  \
# 161         Remote    United States            M              Data Analysis
# 2287        Remote   American Samoa            M  Leadership and Management
# 3188        Remote          Hungary            S  Data Science and Research
# 5451        Remote           Canada            L    Machine Learning and AI
# 5454        Remote       Luxembourg            S  Data Science and Research
# ...            ...              ...          ...                        ...
# 14167       Remote           France            L  Data Science and Research
# 14169       Remote    United States            S    Machine Learning and AI
# 14178       Hybrid       Luxembourg            S  Data Science and Research
# 14188       Remote    United States            M           Data Engineering
# 14191       Remote           Israel            M  Data Science and Research
#
#        employee_expat
# 161              True
# 2287             True
# 3188             True
# 5451             True
# 5454             True
# ...               ...
# 14167            True
# 14169            True
# 14178            True
# 14188            True
# 14191            True
#
# [119 rows x 13 columns]

# %% [markdown]
# Encode categorical variables if necessary (e.g., one-hot encoding, label encoding, etc.).

# %%
df['company_size'] = df['company_size'].replace({'S': 0, 'M': 1, 'L': 2})

# %% [markdown]
# ### 6. Conclusion:

# %% [markdown]
# * The Average salary is 145344.22
# * Tha Max salary is 409500.00
# * The Min salary is 14000.00
# * The Top
# experince level: Senior
# employemnt type: Full-time:
# job title: Data Engineer
# work setting: In-person
# Job category: Data Science and Research
#
# * Relationship between experience level and salary shown to us Exective level recevies the highest salary.
#
# * We can notice a rise in average salaries from 2020 to 2023 with a slight decrease in 2024
# The future trajectory is upward
#
#
# * Relationship between job title and salary and It has been analyzed and shown to us Data Science Tech lead recevies the hightes average salary.
#
# * The elationship to get which country paid the highest average salary and It has been analyzed and shown to us Qatar is paid hightes average salary.
#
# * As we see, we can conclude that the dataset includes work year from 2020 to 2024 with the highest amount of data from the year 2023
#
# * The job title column using word cloud to get the most represented job to indicates its frequency and its shown to us the most represented job is Data Enginner.
#
# * This Pie Chart shows the percentage/proportions of work conditions, and we got these catagories and their %
#
# *   Hybird 2%
# *   Remote 32%
# *   In person 66%

# %% [markdown]
# ### Recommendations
